# %%
import numpy as np # linear algebra
import pandas as pd

# %%
#Loadind Dataset using pandas:
data = pd.read_csv("/kaggle/input/loan-prediction-dataset-2025/loan_dataset_20000.csv")

# %%
# Displaying Dataset, its shape,info and stastical information:
print("Data first three rows: ")
print(data.head(2))
print("********************************************************")
print("Dataset shape: ")
print(data.shape)
print("********************************************************")
print("Dataset info: ")
print(data.info())
print("********************************************************")
print("Dataset stastical description: ")
print(data.describe())
# Out:
# Data first three rows:
#    age  gender marital_status education_level  annual_income  monthly_income  \
# 0   59    Male        Married        Master's       24240.19         2020.02
# 1   72  Female        Married      Bachelor's       20172.98         1681.08
#
#   employment_status  debt_to_income_ratio  credit_score  loan_amount  ...  \
# 0          Employed                 0.074           743     17173.72  ...
# 1          Employed                 0.219           531     22663.89  ...
#
#   loan_term  installment  grade_subgrade  num_of_open_accounts  \
# 0        36       581.88              B5                     7
# 1        60       573.17              F1                     5
#
#   total_credit_limit  current_balance  delinquency_history  public_records  \
# 0           40833.47         24302.07                    1               0
# 1           27968.01         10803.01                    1               0
#
#    num_of_delinquencies  loan_paid_back
# ...

# %%
print(data.isnull().sum())
#No null values so lets move to next step
# Out:
# age                     0
# gender                  0
# marital_status          0
# education_level         0
# annual_income           0
# monthly_income          0
# employment_status       0
# debt_to_income_ratio    0
# credit_score            0
# loan_amount             0
# loan_purpose            0
# interest_rate           0
# loan_term               0
# installment             0
# grade_subgrade          0
# num_of_open_accounts    0
# total_credit_limit      0
# current_balance         0
# delinquency_history     0
# public_records          0
# num_of_delinquencies    0
# loan_paid_back          0
# dtype: int64

# %%
print(data['employment_status'].value_counts())
print("********************************************************")
print(data['loan_paid_back'].value_counts())
data.info()
# Out:
# employment_status
# Employed         13007
# Self-employed     2923
# Unemployed        2113
# Retired           1176
# Student            781
# Name: count, dtype: int64
# ********************************************************
# loan_paid_back
# 1    15998
# 0     4002
# Name: count, dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   age                   20000 non-null  int64
#  1   gender                20000 non-null  object
#  2   marital_status        20000 non-null  object
#  3   education_level       20000 non-null  object
#  4   annual_income         20000 non-null  float64
#  5   monthly_income        20000 non-null  float64
#  6   employment_status     20000 non-null  object
#  7   debt_to_income_ratio  20000 non-null  float64
#  8   credit_score          20000 non-null  int64
# ...

# %%
# changing catogorical column to numbers so ML models can use them to make some predictions:
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
string_col =  data.select_dtypes(include='object')
for col in string_col:
    data[col] = le.fit_transform(data[col])

# %%
X = data.drop('loan_paid_back',axis=1)
y = data['loan_paid_back']

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score
xgb = XGBClassifier()
xgb.fit(X_train,y_train)
pre = xgb.predict(X_test)
acc = accuracy_score(pre,y_test)
acc
# Out:
# 0.8925757575757576
